# %%
import pandas as pd
from sqlalchemy import create_engine
from snowflake.sqlalchemy import URL

from itables import init_notebook_mode, show
init_notebook_mode(all_interactive = True)

engine = create_engine(
    URL(
        account = "UHG-UHGDWAAS",
        user = "KHANG.NGUYEN@UHC.COM",
        authenticator = "externalbrowser",
        role = "AZU_SDRP_VING_PRD_DEVELOPER_ROLE",
        warehouse = "VING_PRD_MNR_HCE_DATAINFRA_WH",
        database = "VING_PRD_TREND_DB",
        schema = "TMP_1M"
    )
)

# %%
from IPython.display import display, HTML

display(HTML("""
<style>
* {
  color: black !important;
  background-color: white !important;
}
</style>
"""))
# Out:
# <style>
# * {
#   color: black !important;
#   background-color: white !important;
# }
# </style>

# %%
print("hello")

# pd.DataFrame({"a":[1,2]}).head()
# Out:
# hello

# %%
df_loc = pd.read_sql("select * from tmp_1m.kn_loc_04082026, limit 500", con = engine)
print(df_loc)

# %%
from IPython.display import display, HTML
display(HTML("<style>.dataframe { color: black !important }</style>"))

# %%
print("Hello")
# Out:
# Hello

# %%
from IPython.display import display, HTML

display(HTML("""
<script>
var out = document.querySelector('.output_area');
if (out) {
  console.log('height:', out.offsetHeight);
  alert('output height = ' + out.offsetHeight + 'px');
}
</script>
"""))

# %%
from IPython.display import display, HTML
display(HTML("""
<style>
.jp-OutputArea, .jp-RenderedText {
  color: var(--vscode-editor-foreground) !important;
}
</style>
"""))
# Out:
# <style>
# .jp-OutputArea, .jp-RenderedText {
#   color: var(--vscode-editor-foreground) !important;
# }
# </style>

# %%
from IPython.display import display, HTML

display(HTML("""
<style>
.jp-Notebook, .jp-OutputArea, .jp-RenderedText {
  background-color: var(--vscode-editor-background) !important;
  color: var(--vscode-editor-foreground) !important;
}
</style>
"""))
# Out:
# <style>
# .jp-Notebook, .jp-OutputArea, .jp-RenderedText {
#   background-color: var(--vscode-editor-background) !important;
#   color: var(--vscode-editor-foreground) !important;
# }
# </style>

# %%
from IPython.display import display, HTML

display(HTML("""
<style>
.jp-OutputArea * {
  all: revert !important;
}
</style>
"""))
# Out:
# <style>
# .jp-OutputArea * {
#   all: revert !important;
# }
# </style>

# %%
from IPython.display import display, HTML
display(HTML("""
<style>
.jp-Notebook, .jp-OutputArea {
  background: var(--vscode-editor-background) !important;
  color: var(--vscode-editor-foreground) !important;
}
</style>
"""))
``
# Out:
#   Cell In[1], line 10
#
#     ``
#
#     ^
#
# SyntaxError: invalid syntax
